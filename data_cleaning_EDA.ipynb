# %%
import pandas as pd
import numpy as np
from src import cleaning
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/apaks/Desktop/Data Science/Python/Python Playground/Projects/Machine Learning Projects/Loan Data from Lending Club/data/loans_full_schema.csv')

# %%
data.head()
# Out:
#                  emp_title  emp_length state homeownership  annual_income  \
# 0  global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1   warehouse office clerk        10.0    HI          RENT        40000.0
# 2                 assembly         3.0    WI          RENT        40000.0
# 3         customer service         1.0    PA          RENT        30000.0
# 4     security supervisor         10.0    CA          RENT        35000.0
#
#    verified_income  debt_to_income  annual_income_joint  \
# 0         Verified           18.01                  NaN
# 1     Not Verified            5.04                  NaN
# 2  Source Verified           21.15                  NaN
# 3     Not Verified           10.16                  NaN
# 4         Verified           57.96              57000.0
#
#   verification_income_joint  debt_to_income_joint  ...  sub_grade  \
# 0                       NaN                   NaN  ...         C3
# 1                       NaN                   NaN  ...         C1
# 2                       NaN                   NaN  ...         D1
# 3                       NaN                   NaN  ...         A3
# 4                  Verified                 37.66  ...         C3
#
#    issue_month  loan_status  initial_listing_status  disbursement_method  \
# 0     Mar-2018      Current                   whole                 Cash
# 1     Feb-2018      Current                   whole                 Cash
# 2     Feb-2018      Current              fractional                 Cash
# 3     Jan-2018      Current                   whole                 Cash
# 4     Mar-2018      Current                   whole                 Cash
#
#     balance  paid_total  paid_principal  paid_interest  paid_late_fees
# 0  27015.86     1999.33          984.14        1015.19             0.0
# 1   4651.37      499.12          348.63         150.49             0.0
# 2   1824.63      281.80          175.37         106.43             0.0
# 3  18853.26     3312.89         2746.74         566.15             0.0
# 4  21430.15     2324.65         1569.85         754.80             0.0
#
# [5 rows x 55 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
data.shape
# Out:
# (10000, 55)

# %%
data.columns
# Out:
# Index(['emp_title', 'emp_length', 'state', 'homeownership', 'annual_income',
#        'verified_income', 'debt_to_income', 'annual_income_joint',
#        'verification_income_joint', 'debt_to_income_joint', 'delinq_2y',
#        'months_since_last_delinq', 'earliest_credit_line',
#        'inquiries_last_12m', 'total_credit_lines', 'open_credit_lines',
#        'total_credit_limit', 'total_credit_utilized',
#        'num_collections_last_12m', 'num_historical_failed_to_pay',
#        'months_since_90d_late', 'current_accounts_delinq',
#        'total_collection_amount_ever', 'current_installment_accounts',
#        'accounts_opened_24m', 'months_since_last_credit_inquiry',
#        'num_satisfactory_accounts', 'num_accounts_120d_past_due',
#        'num_accounts_30d_past_due', 'num_active_debit_accounts',
#        'total_debit_limit', 'num_total_cc_accounts', 'num_open_cc_accounts',
#        'num_cc_carrying_balance', 'num_mort_accounts',
#        'account_never_delinq_percent', 'tax_liens', 'public_record_bankrupt',
#        'loan_purpose', 'application_type', 'loan_amount', 'term',
#        'interest_rate', 'installment', 'grade', 'sub_grade', 'issue_month',
#        'loan_status', 'initial_listing_status', 'disbursement_method',
#        'balance', 'paid_total', 'paid_principal', 'paid_interest',
#        'paid_late_fees'],
#       dtype='object')

# %%
# copy of the original data
df = data.copy()

# %% [markdown]
# drop unnecessary columns

# %%
df = cleaning.drop_leakage_columns(df)

# %%
df.head()
# Out:
#    emp_length state homeownership  annual_income  verified_income  \
# 0         3.0    NJ      MORTGAGE        90000.0         Verified
# 1        10.0    HI          RENT        40000.0     Not Verified
# 2         3.0    WI          RENT        40000.0  Source Verified
# 3         1.0    PA          RENT        30000.0     Not Verified
# 4        10.0    CA          RENT        35000.0         Verified
#
#    debt_to_income  delinq_2y  months_since_last_delinq  earliest_credit_line  \
# 0           18.01          0                      38.0                  2001
# 1            5.04          0                       NaN                  1996
# 2           21.15          0                      28.0                  2006
# 3           10.16          0                       NaN                  2007
# 4           57.96          0                       NaN                  2008
#
#    inquiries_last_12m  total_credit_lines  open_credit_lines  \
# 0                   6                  28                 10
# 1                   1                  30                 14
# 2                   4                  31                 10
# 3                   0                   4                  4
# 4                   7                  22                 16
#
#    total_credit_limit  total_credit_utilized  num_collections_last_12m  \
# 0               70795                  38767                         0
# 1               28800                   4321                         0
# 2               24193                  16000                         0
# 3               25400                   4997                         0
# 4               69839                  52722                         0
#
#    num_historical_failed_to_pay  months_since_90d_late  \
# 0                             0                   38.0
# 1                             1                    NaN
# 2                             0                   28.0
# 3                             1                    NaN
# 4                             0                    NaN
#
#    current_accounts_delinq  total_collection_amount_ever  \
# 0                        0                          1250
# 1                        0                             0
# 2                        0                           432
# 3                        0                             0
# 4                        0                             0
#
#    current_installment_accounts  accounts_opened_24m  \
# 0                             2                    5
# 1                             0                   11
# 2                             1                   13
# 3                             1                    1
# 4                             1                    6
#
#    months_since_last_credit_inquiry  num_satisfactory_accounts  \
# 0                               5.0                         10
# 1                               8.0                         14
# 2                               7.0                         10
# 3                              15.0                          4
# 4                               4.0                         16
#
#    num_accounts_120d_past_due  num_accounts_30d_past_due  \
# 0                         0.0                          0
# 1                         0.0                          0
# 2                         0.0                          0
# 3                         0.0                          0
# 4                         0.0                          0
#
#    num_active_debit_accounts  total_debit_limit  num_total_cc_accounts  \
# 0                          2              11100                     14
# 1                          3              16500                     24
# 2                          3               4300                     14
# 3                          2              19400                      3
# 4                         10              32700                     20
#
#    num_open_cc_accounts  num_cc_carrying_balance  num_mort_accounts  \
# 0                     8                        6                  1
# 1                    14                        4                  0
# 2                     8                        6                  0
# 3                     3                        2                  0
# 4                    15                       13                  0
#
#    account_never_delinq_percent  tax_liens  public_record_bankrupt  \
# 0                          92.9          0                       0
# 1                         100.0          0                       1
# 2                          93.5          0                       0
# 3                         100.0          1                       0
# 4                         100.0          0                       0
#
#          loan_purpose application_type  loan_amount  term  interest_rate  \
# 0              moving       individual        28000    60          14.07
# 1  debt_consolidation       individual         5000    36          12.61
# 2               other       individual         2000    36          17.09
# 3  debt_consolidation       individual        21600    36           6.72
# 4         credit_card            joint        23000    36          14.07
#
#    installment grade sub_grade issue_month initial_listing_status  \
# 0       652.53     C        C3    Mar-2018                  whole
# 1       167.54     C        C1    Feb-2018                  whole
# 2        71.40     D        D1    Feb-2018             fractional
# 3       664.19     A        A3    Jan-2018                  whole
# 4       786.87     C        C3    Mar-2018                  whole
#
#   disbursement_method
# 0                Cash
# 1                Cash
# 2                Cash
# 3                Cash
# 4                Cash

# %% [markdown]
# Missing values in months_since_last_delinq and months_since_90d_late
# - impute them with max + 1, 0 can be misinterpretted by the model.

# %%
df = cleaning.fill_with_max(df, 'months_since_last_delinq')
df = cleaning.fill_with_max(df, 'months_since_90d_late')

# %% [markdown]
# Missing values in emp_length, debt_to_income
# - impute them with median

# %%
df['emp_length'] = df['emp_length'].fillna(df['emp_length'].median())
df['debt_to_income'] = df['debt_to_income'].fillna(df['debt_to_income'].median())

# %% [markdown]
# missing values in months_since_last_credit_inquiry and num_accounts_120d_past_due
# - impute with max + 1

# %%
df = cleaning.fill_with_max(df, 'months_since_last_credit_inquiry')
df = cleaning.fill_with_max(df, 'num_accounts_120d_past_due')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   emp_length                        10000 non-null  float64
#  1   state                             10000 non-null  object
#  2   homeownership                     10000 non-null  object
#  3   annual_income                     10000 non-null  float64
#  4   verified_income                   10000 non-null  object
#  5   debt_to_income                    10000 non-null  float64
#  6   delinq_2y                         10000 non-null  int64
#  7   months_since_last_delinq          10000 non-null  float64
#  8   earliest_credit_line              10000 non-null  int64
#  9   inquiries_last_12m                10000 non-null  int64
#  10  total_credit_lines                10000 non-null  int64
#  11  open_credit_lines                 10000 non-null  int64
#  12  total_credit_limit                10000 non-null  int64
#  13  total_credit_utilized             10000 non-null  int64
#  14  num_collections_last_12m          10000 non-null  int64
#  15  num_historical_failed_to_pay      10000 non-null  int64
#  16  months_since_90d_late             10000 non-null  float64
#  17  current_accounts_delinq           10000 non-null  int64
#  18  total_collection_amount_ever      10000 non-null  int64
#  19  current_installment_accounts      10000 non-null  int64
#  20  accounts_opened_24m               10000 non-null  int64
#  21  months_since_last_credit_inquiry  10000 non-null  float64
#  22  num_satisfactory_accounts         10000 non-null  int64
#  23  num_accounts_120d_past_due        10000 non-null  float64
#  24  num_accounts_30d_past_due         10000 non-null  int64
#  25  num_active_debit_accounts         10000 non-null  int64
#  26  total_debit_limit                 10000 non-null  int64
#  27  num_total_cc_accounts             10000 non-null  int64
#  28  num_open_cc_accounts              10000 non-null  int64
#  29  num_cc_carrying_balance           10000 non-null  int64
#  30  num_mort_accounts                 10000 non-null  int64
#  31  account_never_delinq_percent      10000 non-null  float64
#  32  tax_liens                         10000 non-null  int64
#  33  public_record_bankrupt            10000 non-null  int64
#  34  loan_purpose                      10000 non-null  object
#  35  application_type                  10000 non-null  object
#  36  loan_amount                       10000 non-null  int64
#  37  term                              10000 non-null  int64
#  38  interest_rate                     10000 non-null  float64
#  39  installment                       10000 non-null  float64
#  40  grade                             10000 non-null  object
#  41  sub_grade                         10000 non-null  object
#  42  issue_month                       10000 non-null  object
#  43  initial_listing_status            10000 non-null  object
#  44  disbursement_method               10000 non-null  object
# dtypes: float64(10), int64(25), object(10)
# memory usage: 3.4+ MB

# %%
df.shape
# Out:
# (10000, 45)

# %%
df.head()
# Out:
#    emp_length state homeownership  annual_income  verified_income  \
# 0         3.0    NJ      MORTGAGE        90000.0         Verified
# 1        10.0    HI          RENT        40000.0     Not Verified
# 2         3.0    WI          RENT        40000.0  Source Verified
# 3         1.0    PA          RENT        30000.0     Not Verified
# 4        10.0    CA          RENT        35000.0         Verified
#
#    debt_to_income  delinq_2y  months_since_last_delinq  earliest_credit_line  \
# 0           18.01          0                      38.0                  2001
# 1            5.04          0                     119.0                  1996
# 2           21.15          0                      28.0                  2006
# 3           10.16          0                     119.0                  2007
# 4           57.96          0                     119.0                  2008
#
#    inquiries_last_12m  total_credit_lines  open_credit_lines  \
# 0                   6                  28                 10
# 1                   1                  30                 14
# 2                   4                  31                 10
# 3                   0                   4                  4
# 4                   7                  22                 16
#
#    total_credit_limit  total_credit_utilized  num_collections_last_12m  \
# 0               70795                  38767                         0
# 1               28800                   4321                         0
# 2               24193                  16000                         0
# 3               25400                   4997                         0
# 4               69839                  52722                         0
#
#    num_historical_failed_to_pay  months_since_90d_late  \
# 0                             0                   38.0
# 1                             1                  129.0
# 2                             0                   28.0
# 3                             1                  129.0
# 4                             0                  129.0
#
#    current_accounts_delinq  total_collection_amount_ever  \
# 0                        0                          1250
# 1                        0                             0
# 2                        0                           432
# 3                        0                             0
# 4                        0                             0
#
#    current_installment_accounts  accounts_opened_24m  \
# 0                             2                    5
# 1                             0                   11
# 2                             1                   13
# 3                             1                    1
# 4                             1                    6
#
#    months_since_last_credit_inquiry  num_satisfactory_accounts  \
# 0                               5.0                         10
# 1                               8.0                         14
# 2                               7.0                         10
# 3                              15.0                          4
# 4                               4.0                         16
#
#    num_accounts_120d_past_due  num_accounts_30d_past_due  \
# 0                         0.0                          0
# 1                         0.0                          0
# 2                         0.0                          0
# 3                         0.0                          0
# 4                         0.0                          0
#
#    num_active_debit_accounts  total_debit_limit  num_total_cc_accounts  \
# 0                          2              11100                     14
# 1                          3              16500                     24
# 2                          3               4300                     14
# 3                          2              19400                      3
# 4                         10              32700                     20
#
#    num_open_cc_accounts  num_cc_carrying_balance  num_mort_accounts  \
# 0                     8                        6                  1
# 1                    14                        4                  0
# 2                     8                        6                  0
# 3                     3                        2                  0
# 4                    15                       13                  0
#
#    account_never_delinq_percent  tax_liens  public_record_bankrupt  \
# 0                          92.9          0                       0
# 1                         100.0          0                       1
# 2                          93.5          0                       0
# 3                         100.0          1                       0
# 4                         100.0          0                       0
#
#          loan_purpose application_type  loan_amount  term  interest_rate  \
# 0              moving       individual        28000    60          14.07
# 1  debt_consolidation       individual         5000    36          12.61
# 2               other       individual         2000    36          17.09
# 3  debt_consolidation       individual        21600    36           6.72
# 4         credit_card            joint        23000    36          14.07
#
#    installment grade sub_grade issue_month initial_listing_status  \
# 0       652.53     C        C3    Mar-2018                  whole
# 1       167.54     C        C1    Feb-2018                  whole
# 2        71.40     D        D1    Feb-2018             fractional
# 3       664.19     A        A3    Jan-2018                  whole
# 4       786.87     C        C3    Mar-2018                  whole
#
#   disbursement_method
# 0                Cash
# 1                Cash
# 2                Cash
# 3                Cash
# 4                Cash

# %%
# save the current cleaned data into csv

df.to_csv('C:/Users/apaks/Desktop/Data Science/Python/Python Playground/Projects/Machine Learning Projects/Loan Data from Lending Club/data/cleaned_data_state_1.csv')

# %% [markdown]
# Check value counts for each column for any dicrepencies

# %%
for col in df.columns:
    print(df[col].value_counts())
    print()
# Out:
# emp_length
# 10.0    3332
# 6.0     1221
# 2.0      967
# 3.0      862
# 0.0      690
# 1.0      685
# 5.0      645
# 4.0      611
# 7.0      368
# 9.0      312
# 8.0      307
# Name: count, dtype: int64
#
# state
# CA    1330
# TX     806
# NY     793
# FL     732
# IL     382
# NJ     338
# OH     338
# GA     334
# NC     299
# PA     298
# VA     261
# AZ     255
# MD     247
# MI     245
# MA     237
# CO     235
# WA     235
# CT     181
# IN     178
# TN     167
# MN     159
# MO     159
# NV     158
# SC     145
# OR     130
# WI     128
# AL     122
# KY      97
# LA      96
# KS      89
# OK      81
# MS      72
# AR      70
# WV      68
# UT      61
# NE      56
# RI      53
# NH      47
# NM      43
# ID      38
# HI      35
# AK      33
# ME      26
# DE      24
# MT      24
# VT      23
# SD      20
# WY      19
# DC      19
# ND      14
# Name: count, dtype: int64
#
# homeownership
# MORTGAGE    4789
# RENT        3858
# OWN         1353
# Name: count, dtype: int64
#
# annual_income
# 60000.0     383
# 50000.0     350
# 65000.0     314
# 70000.0     273
# 75000.0     260
#            ...
# 43900.0       1
# 62800.0       1
# 74870.0       1
# 141000.0      1
# 75400.0       1
# Name: count, Length: 1463, dtype: int64
#
# verified_income
# Source Verified    4116
# Not Verified       3594
# Verified           2290
# Name: count, dtype: int64
#
# debt_to_income
# 17.57    29
# 0.00     28
# 16.11    14
# 20.66    12
# 13.20    12
#          ..
# 13.12     1
# 5.51      1
# 55.34     1
# 63.39     1
# 36.02     1
# Name: count, Length: 3673, dtype: int64
#
# delinq_2y
# 0     8576
# 1     1011
# 2      258
# 3       88
# 4       34
# 5       10
# 8        7
# 7        7
# 6        3
# 9        3
# 10       2
# 13       1
# Name: count, dtype: int64
#
# months_since_last_delinq
# 119.0    5658
# 25.0       87
# 9.0        86
# 24.0       85
# 12.0       83
#          ...
# 100.0       1
# 109.0       1
# 88.0        1
# 106.0       1
# 98.0        1
# Name: count, Length: 98, dtype: int64
#
# earliest_credit_line
# 2006    768
# 2005    730
# 2004    672
# 2007    636
# 2003    620
# 2002    538
# 2001    495
# 2000    469
# 1999    406
# 1998    377
# 2008    371
# 1997    289
# 1996    282
# 1995    254
# 1994    244
# 2009    243
# 2010    242
# 2012    236
# 2011    236
# 2013    229
# 2014    196
# 1993    174
# 1990    137
# 1991    132
# 1992    127
# 1989    125
# 1987    113
# 1988     95
# 1986     84
# 1985     83
# 1984     67
# 1983     60
# 1982     44
# 1981     30
# 1979     28
# 1978     23
# 1980     23
# 1977     21
# 2015     17
# 1974     14
# 1976     13
# 1972     10
# 1975      9
# 1971      9
# 1973      9
# 1969      7
# 1970      4
# 1963      2
# 1967      2
# 1968      2
# 1966      1
# 1965      1
# 1964      1
# Name: count, dtype: int64
#
# inquiries_last_12m
# 0     3060
# 1     2460
# 2     1649
# 3     1053
# 4      610
# 5      422
# 6      242
# 7      155
# 8      116
# 9       69
# 10      51
# 11      40
# 12      25
# 13      13
# 15       8
# 14       7
# 18       5
# 17       3
# 16       3
# 22       2
# 20       2
# 26       1
# 19       1
# 24       1
# 21       1
# 29       1
# Name: count, dtype: int64
#
# total_credit_lines
# 18    379
# 19    375
# 16    371
# 14    371
# 15    365
#      ...
# 87      2
# 76      2
# 72      1
# 83      1
# 77      1
# Name: count, Length: 78, dtype: int64
#
# open_credit_lines
# 9     837
# 10    814
# 7     788
# 8     779
# 11    712
# 6     697
# 12    611
# 5     575
# 13    569
# 14    456
# 15    418
# 16    368
# 4     342
# 17    277
# 18    249
# 3     234
# 19    202
# 20    163
# 22    140
# 21    138
# 23    110
# 2      96
# 24     80
# 25     64
# 26     59
# 27     43
# 28     32
# 29     27
# 30     18
# 1      16
# 31     14
# 36     13
# 35     11
# 33     10
# 38      9
# 32      8
# 37      5
# 34      4
# 39      3
# 0       2
# 40      2
# 41      2
# 46      1
# 51      1
# 42      1
# Name: count, dtype: int64
#
# total_credit_limit
# 21200     9
# 14500     8
# 17200     7
# 29300     7
# 28300     7
#          ..
# 551253    1
# 68084     1
# 284156    1
# 43846     1
# 92143     1
# Name: count, Length: 9119, dtype: int64
#
# total_credit_utilized
# 0         28
# 16252      4
# 30329      3
# 104784     3
# 14002      3
#           ..
# 36484      1
# 98593      1
# 36371      1
# 20609      1
# 19287      1
# Name: count, Length: 9497, dtype: int64
#
# num_collections_last_12m
# 0    9873
# 1     117
# 2       9
# 3       1
# Name: count, dtype: int64
#
# num_historical_failed_to_pay
# 0     8586
# 1     1288
# 2       78
# 3       27
# 4       12
# 5        4
# 7        2
# 6        2
# 52       1
# Name: count, dtype: int64
#
# months_since_90d_late
# 129.0    7715
# 34.0       48
# 45.0       45
# 60.0       44
# 67.0       43
#          ...
# 120.0       1
# 107.0       1
# 90.0        1
# 83.0        1
# 98.0        1
# Name: count, Length: 107, dtype: int64
#
# current_accounts_delinq
# 0    9999
# 1       1
# Name: count, dtype: int64
#
# total_collection_amount_ever
# 0       8635
# 100       12
# 50        10
# 150        9
# 96         9
#         ...
# 4562       1
# 3191       1
# 968        1
# 144        1
# 1323       1
# Name: count, Length: 896, dtype: int64
#
# current_installment_accounts
# 1     2636
# 2     2291
# 0     1414
# 3     1406
# 4      747
# 5      434
# 6      257
# 7      196
# 8      137
# 9      104
# 10      74
# 11      65
# 12      60
# 15      34
# 13      32
# 14      29
# 16      22
# 17      15
# 18      12
# 19      10
# 20       9
# 21       5
# 23       3
# 28       2
# 35       1
# 22       1
# 27       1
# 24       1
# 25       1
# 33       1
# Name: count, dtype: int64
#
# accounts_opened_24m
# 2     1532
# 3     1520
# 4     1328
# 5     1077
# 1     1073
# 6      858
# 7      654
# 0      527
# 8      429
# 9      280
# 10     242
# 11     150
# 12     119
# 13      69
# 14      44
# 15      31
# 16      24
# 17      11
# 18      10
# 21       6
# 19       6
# 20       5
# 22       2
# 29       1
# 26       1
# 23       1
# Name: count, dtype: int64
#
# months_since_last_credit_inquiry
# 25.0    1271
# 1.0      796
# 2.0      740
# 0.0      693
# 3.0      663
# 4.0      651
# 5.0      576
# 6.0      554
# 7.0      510
# 8.0      473
# 9.0      385
# 10.0     375
# 11.0     279
# 13.0     268
# 12.0     247
# 14.0     226
# 15.0     215
# 16.0     183
# 18.0     172
# 17.0     166
# 19.0     131
# 21.0     108
# 20.0     106
# 22.0     103
# 23.0      76
# 24.0      33
# Name: count, dtype: int64
#
# num_satisfactory_accounts
# 9     841
# 10    812
# 7     791
# 8     787
# 11    709
# 6     695
# 12    609
# 5     573
# 13    566
# 14    457
# 15    414
# 16    369
# 4     349
# 17    279
# 18    242
# 3     236
# 19    205
# 20    164
# 22    139
# 21    138
# 23    107
# 2      98
# 24     78
# 25     65
# 26     58
# 27     41
# 28     31
# 29     28
# 30     17
# 1      16
# 31     14
# 36     13
# 35     11
# 33     11
# 38      9
# 32      8
# 37      5
# 39      3
# 34      3
# 0       2
# 40      2
# 41      2
# 46      1
# 51      1
# 42      1
# Name: count, dtype: int64
#
# num_accounts_120d_past_due
# 0.0    9682
# 1.0     318
# Name: count, dtype: int64
#
# num_accounts_30d_past_due
# 0    9999
# 1       1
# Name: count, dtype: int64
#
# num_active_debit_accounts
# 3     1987
# 2     1985
# 4     1568
# 1     1379
# 5     1044
# 6      619
# 7      392
# 0      333
# 8      276
# 9      154
# 10      99
# 11      61
# 12      43
# 13      24
# 15      11
# 14      11
# 16       3
# 23       2
# 18       2
# 20       2
# 29       1
# 17       1
# 22       1
# 21       1
# 32       1
# Name: count, dtype: int64
#
# total_debit_limit
# 0         135
# 10000      70
# 5000       67
# 3000       66
# 7500       66
#          ...
# 93900       1
# 75600       1
# 19970       1
# 91800       1
# 111200      1
# Name: count, Length: 1222, dtype: int64
#
# num_total_cc_accounts
# 8     659
# 10    648
# 7     644
# 9     618
# 6     617
# 11    579
# 12    503
# 14    484
# 5     483
# 13    470
# 4     415
# 15    392
# 16    371
# 17    336
# 3     304
# 18    284
# 19    267
# 20    223
# 21    194
# 22    177
# 2     165
# 23    163
# 24    137
# 27    104
# 26    104
# 25    104
# 29     71
# 30     64
# 28     62
# 31     53
# 32     48
# 33     40
# 35     29
# 34     24
# 37     24
# 36     22
# 38     18
# 39     15
# 40     11
# 43      9
# 42      8
# 44      8
# 46      8
# 45      7
# 41      6
# 48      6
# 47      5
# 49      5
# 55      4
# 53      2
# 50      1
# 57      1
# 51      1
# 64      1
# 66      1
# 58      1
# Name: count, dtype: int64
#
# num_open_cc_accounts
# 5     1107
# 6     1018
# 7      991
# 4      937
# 8      839
# 3      750
# 9      693
# 10     573
# 2      505
# 11     481
# 12     379
# 13     316
# 14     245
# 15     205
# 16     163
# 1      140
# 17     128
# 18     111
# 19      92
# 20      65
# 21      51
# 22      47
# 23      42
# 24      26
# 25      21
# 26      13
# 27      11
# 32       7
# 0        7
# 29       7
# 28       7
# 30       4
# 34       4
# 33       4
# 35       3
# 31       3
# 36       2
# 38       1
# 46       1
# 41       1
# Name: count, dtype: int64
#
# num_cc_carrying_balance
# 4     1521
# 3     1438
# 5     1331
# 2     1214
# 6     1009
# 7      822
# 1      599
# 8      521
# 9      403
# 10     290
# 11     211
# 12     156
# 0      125
# 13     112
# 14      70
# 15      68
# 16      34
# 17      18
# 19      14
# 18      13
# 21       9
# 20       6
# 22       5
# 25       3
# 24       2
# 23       2
# 29       1
# 27       1
# 43       1
# 36       1
# Name: count, dtype: int64
#
# num_mort_accounts
# 0     4484
# 1     1755
# 2     1529
# 3     1071
# 4      556
# 5      301
# 6      170
# 7       72
# 8       36
# 9       11
# 10       9
# 13       2
# 12       2
# 11       1
# 14       1
# Name: count, dtype: int64
#
# account_never_delinq_percent
# 100.0    5656
# 91.7      116
# 93.8      115
# 90.9      112
# 92.9      106
#          ...
# 55.0        1
# 80.9        1
# 76.7        1
# 52.0        1
# 89.6        1
# Name: count, Length: 282, dtype: int64
#
# tax_liens
# 0     9754
# 1      165
# 2       48
# 3       18
# 4        7
# 5        5
# 7        1
# 52       1
# 6        1
# Name: count, dtype: int64
#
# public_record_bankrupt
# 0    8785
# 1    1195
# 2      17
# 3       3
# Name: count, dtype: int64
#
# loan_purpose
# debt_consolidation    5144
# credit_card           2249
# other                  914
# home_improvement       680
# major_purchase         303
# medical                162
# house                  151
# car                    131
# small_business         125
# moving                  69
# vacation                62
# renewable_energy        10
# Name: count, dtype: int64
#
# application_type
# individual    8505
# joint         1495
# Name: count, dtype: int64
#
# loan_amount
# 10000    1000
# 20000     708
# 15000     586
# 12000     471
# 40000     438
#          ...
# 11775       1
# 20975       1
# 16050       1
# 26575       1
# 35400       1
# Name: count, Length: 612, dtype: int64
#
# term
# 36    6970
# 60    3030
# Name: count, dtype: int64
#
# interest_rate
# 9.93     390
# 11.99    376
# 9.44     367
# 13.59    347
# 10.42    346
# 12.62    333
# 7.35     325
# 14.08    318
# 6.72     312
# 10.91    306
# 15.05    304
# 16.02    284
# 9.43     280
# 6.08     277
# 10.90    275
# 7.97     274
# 12.61    264
# 11.98    255
# 9.92     248
# 7.34     243
# 5.32     234
# 13.58    225
# 7.96     211
# 6.07     202
# 15.04    199
# 19.03    197
# 16.01    196
# 17.09    195
# 10.41    194
# 6.71     192
# 5.31     188
# 14.07    183
# 18.06    176
# 21.45    172
# 18.45    146
# 20.00    137
# 17.47    124
# 19.42    114
# 20.39     93
# 21.85     90
# 26.30     53
# 25.82     47
# 24.85     42
# 26.77     38
# 23.88     37
# 28.72     31
# 24.84     31
# 22.91     28
# 25.81     26
# 23.87     20
# 22.90     13
# 30.79     11
# 30.17      9
# 29.69      9
# 30.65      5
# 30.75      4
# 6.00       3
# 30.94      1
# Name: count, dtype: int64
#
# installment
# 313.23    41
# 307.50    37
# 320.05    35
# 304.59    34
# 351.67    28
#           ..
# 375.87     1
# 134.67     1
# 321.64     1
# 404.79     1
# 97.51      1
# Name: count, Length: 3540, dtype: int64
#
# grade
# B    3037
# C    2653
# A    2459
# D    1446
# E     335
# F      58
# G      12
# Name: count, dtype: int64
#
# sub_grade
# B1    647
# B2    638
# B5    631
# C1    597
# B4    581
# C2    572
# A4    568
# B3    540
# A3    504
# C4    503
# C3    501
# A5    485
# A2    480
# C5    480
# A1    422
# D2    323
# D1    319
# D3    311
# D5    262
# D4    231
# E5     91
# E3     73
# E4     73
# E2     57
# E1     41
# F1     31
# G1     11
# F3      9
# F2      9
# F4      5
# F5      4
# G4      1
# Name: count, dtype: int64
#
# issue_month
# Mar-2018    3617
# Jan-2018    3395
# Feb-2018    2988
# Name: count, dtype: int64
#
# initial_listing_status
# whole         8206
# fractional    1794
# Name: count, dtype: int64
#
# disbursement_method
# Cash         9284
# DirectPay     716
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    emp_length state homeownership  annual_income  verified_income  \
# 0         3.0    NJ      MORTGAGE        90000.0         Verified
# 1        10.0    HI          RENT        40000.0     Not Verified
# 2         3.0    WI          RENT        40000.0  Source Verified
# 3         1.0    PA          RENT        30000.0     Not Verified
# 4        10.0    CA          RENT        35000.0         Verified
#
#    debt_to_income  delinq_2y  months_since_last_delinq  earliest_credit_line  \
# 0           18.01          0                      38.0                  2001
# 1            5.04          0                     119.0                  1996
# 2           21.15          0                      28.0                  2006
# 3           10.16          0                     119.0                  2007
# 4           57.96          0                     119.0                  2008
#
#    inquiries_last_12m  total_credit_lines  open_credit_lines  \
# 0                   6                  28                 10
# 1                   1                  30                 14
# 2                   4                  31                 10
# 3                   0                   4                  4
# 4                   7                  22                 16
#
#    total_credit_limit  total_credit_utilized  num_collections_last_12m  \
# 0               70795                  38767                         0
# 1               28800                   4321                         0
# 2               24193                  16000                         0
# 3               25400                   4997                         0
# 4               69839                  52722                         0
#
#    num_historical_failed_to_pay  months_since_90d_late  \
# 0                             0                   38.0
# 1                             1                  129.0
# 2                             0                   28.0
# 3                             1                  129.0
# 4                             0                  129.0
#
#    current_accounts_delinq  total_collection_amount_ever  \
# 0                        0                          1250
# 1                        0                             0
# 2                        0                           432
# 3                        0                             0
# 4                        0                             0
#
#    current_installment_accounts  accounts_opened_24m  \
# 0                             2                    5
# 1                             0                   11
# 2                             1                   13
# 3                             1                    1
# 4                             1                    6
#
#    months_since_last_credit_inquiry  num_satisfactory_accounts  \
# 0                               5.0                         10
# 1                               8.0                         14
# 2                               7.0                         10
# 3                              15.0                          4
# 4                               4.0                         16
#
#    num_accounts_120d_past_due  num_accounts_30d_past_due  \
# 0                         0.0                          0
# 1                         0.0                          0
# 2                         0.0                          0
# 3                         0.0                          0
# 4                         0.0                          0
#
#    num_active_debit_accounts  total_debit_limit  num_total_cc_accounts  \
# 0                          2              11100                     14
# 1                          3              16500                     24
# 2                          3               4300                     14
# 3                          2              19400                      3
# 4                         10              32700                     20
#
#    num_open_cc_accounts  num_cc_carrying_balance  num_mort_accounts  \
# 0                     8                        6                  1
# 1                    14                        4                  0
# 2                     8                        6                  0
# 3                     3                        2                  0
# 4                    15                       13                  0
#
#    account_never_delinq_percent  tax_liens  public_record_bankrupt  \
# 0                          92.9          0                       0
# 1                         100.0          0                       1
# 2                          93.5          0                       0
# 3                         100.0          1                       0
# 4                         100.0          0                       0
#
#          loan_purpose application_type  loan_amount  term  interest_rate  \
# 0              moving       individual        28000    60          14.07
# 1  debt_consolidation       individual         5000    36          12.61
# 2               other       individual         2000    36          17.09
# 3  debt_consolidation       individual        21600    36           6.72
# 4         credit_card            joint        23000    36          14.07
#
#    installment grade sub_grade issue_month initial_listing_status  \
# 0       652.53     C        C3    Mar-2018                  whole
# 1       167.54     C        C1    Feb-2018                  whole
# 2        71.40     D        D1    Feb-2018             fractional
# 3       664.19     A        A3    Jan-2018                  whole
# 4       786.87     C        C3    Mar-2018                  whole
#
#   disbursement_method
# 0                Cash
# 1                Cash
# 2                Cash
# 3                Cash
# 4                Cash

# %%
# change_credit_line to years_since_first_credit

df['earliest_credit_line'] = pd.Timestamp.now().year - df['earliest_credit_line']

# %%
df.rename(columns={
    'earliest_credit_line': 'years_since_first_credit'
    }, inplace=True)

# %%
# dividing columns into 3 dataframes - (borrower_profile, credit_history, loan_details) and include target column in each for EDA

borrower_profile_df = df[['emp_length', 'state', 'homeownership', 'annual_income', 'verified_income', 'debt_to_income', 'interest_rate']]

credit_history_df = df[['delinq_2y', 'months_since_last_delinq', 'years_since_first_credit', 'inquiries_last_12m', 'total_credit_lines', 'open_credit_lines', 'total_credit_limit', 'total_credit_utilized', 'num_collections_last_12m', 'num_historical_failed_to_pay', 'months_since_90d_late', 'current_accounts_delinq', 'total_collection_amount_ever', 'current_installment_accounts', 'accounts_opened_24m', 'months_since_last_credit_inquiry', 'num_satisfactory_accounts', 'num_accounts_120d_past_due', 'num_accounts_30d_past_due', 'num_active_debit_accounts', 'total_debit_limit', 'num_total_cc_accounts', 'num_open_cc_accounts', 'num_cc_carrying_balance', 'num_mort_accounts', 'account_never_delinq_percent', 'tax_liens', 'public_record_bankrupt', 'interest_rate']]

loan_details_df = df[['loan_purpose', 'application_type', 'loan_amount', 'term', 'installment', 'grade', 'sub_grade', 'issue_month', 'initial_listing_status', 'disbursement_method','interest_rate']]

# %%
borrower_profile_df.shape[1] + credit_history_df.shape[1] + loan_details_df.shape[1]
# Out:
# 47

# %% [markdown]
# ## EDA - borrower's profile

# %%
temp_df = borrower_profile_df.copy()

# %%
temp_df.head()
# Out:
#    emp_length state homeownership  annual_income  verified_income  \
# 0         3.0    NJ      MORTGAGE        90000.0         Verified
# 1        10.0    HI          RENT        40000.0     Not Verified
# 2         3.0    WI          RENT        40000.0  Source Verified
# 3         1.0    PA          RENT        30000.0     Not Verified
# 4        10.0    CA          RENT        35000.0         Verified
#
#    debt_to_income  interest_rate
# 0           18.01          14.07
# 1            5.04          12.61
# 2           21.15          17.09
# 3           10.16           6.72
# 4           57.96          14.07

# %% [markdown]
# Categorical Columns

# %%
cat_cols = ['emp_length', 'state', 'homeownership', 'verified_income']

for col in cat_cols:
    plt.figure(figsize=(10,6))
    temp_df[col].value_counts().plot(kind='bar')
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data = temp_df, x= col, y = 'interest_rate')
    plt.xticks(rotation = 90)
    plt.show()

# %%
# since renters have slightly higher interest rates, therefore change the categories to is_renter or not

temp_df['is_renter'] = temp_df['homeownership'].replace({
    'RENT': 1,
    'OWN': 0,
    'MORTGAGE': 0
})
# Out:
# C:\Users\apaks\AppData\Local\Temp\ipykernel_20140\2655747276.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   temp_df['is_renter'] = temp_df['homeownership'].replace({

# %%
# high cardiniality in states column. less than 400 values counts of the states, group them to 'others'

state_counts = temp_df['state'].value_counts()
rare_states = state_counts[state_counts < 300].index
temp_df['state_grouped'] = temp_df['state'].replace(rare_states, 'other')

# %%
for col in cat_cols:
    temp_df[col].value_counts().sort_values().plot(kind= 'bar')
    plt.show()

# %% [markdown]
# Numerical Columns

# %%
temp_df['log_transformed_annual_income'] = np.log1p(temp_df['annual_income'])
sns.histplot(np.log1p(temp_df['annual_income']), kde=True)
# Out:
# <Axes: xlabel='annual_income', ylabel='Count'>

# %%
sns.histplot(data= temp_df, x = 'debt_to_income', kde=True)
# Out:
# <Axes: xlabel='debt_to_income', ylabel='Count'>

# %%
sns.histplot(np.log1p(temp_df['debt_to_income']), kde=True)
temp_df['log_transformed_debit_to_income'] = np.log1p(temp_df['debt_to_income'])

# %%
sns.scatterplot(temp_df, x = 'log_transformed_annual_income', y = 'interest_rate')
# Out:
# <Axes: xlabel='log_transformed_annual_income', ylabel='interest_rate'>

# %%
sns.scatterplot(temp_df, x = 'log_transformed_debit_to_income', y = 'interest_rate')
# Out:
# <Axes: xlabel='log_transformed_debit_to_income', ylabel='interest_rate'>

# %%
borrower_profile_df = temp_df

# %% [markdown]
# ## EDA - Credit History

# %%
temp_df = credit_history_df.copy()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(credit_history_df.corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
temp_df.columns
# Out:
# Index(['delinq_2y', 'months_since_last_delinq', 'years_since_first_credit',
#        'inquiries_last_12m', 'total_credit_lines', 'open_credit_lines',
#        'total_credit_limit', 'total_credit_utilized',
#        'num_collections_last_12m', 'num_historical_failed_to_pay',
#        'months_since_90d_late', 'current_accounts_delinq',
#        'total_collection_amount_ever', 'current_installment_accounts',
#        'accounts_opened_24m', 'months_since_last_credit_inquiry',
#        'num_satisfactory_accounts', 'num_accounts_120d_past_due',
#        'num_accounts_30d_past_due', 'num_active_debit_accounts',
#        'total_debit_limit', 'num_total_cc_accounts', 'num_open_cc_accounts',
#        'num_cc_carrying_balance', 'num_mort_accounts',
#        'account_never_delinq_percent', 'tax_liens', 'public_record_bankrupt',
#        'interest_rate'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.heatmap(temp_df.corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
# remove num_satisfactory_accounts --> heavily correlated to open_credit_lines
# remove current_accounts_delinq --> heavily correlated with num_accounts_30d_past_due

temp_df.drop(columns = ['num_satisfactory_accounts', 'current_accounts_delinq'], inplace=True)

# %%
# remove total_credit_lines --> heavily correlated with open_credit_lines
# remove num_total_cc_accounts --> heavily correlated with open_credit_lines
# remove num_open_cc_accounts --> correlated with open_credit_lines
# remove num_cc_carrying_balance --> correlated with num_open_cc_accounts 

temp_df.drop(columns = ['total_credit_lines', 'num_total_cc_accounts', 'num_open_cc_accounts', 'num_cc_carrying_balance'], inplace = True)

# %%
# drop tax_liens as correlation with num_historical_failed_to_pay is high and num_historical_fail_to_pay has higher correlation with interest_rate than tax_liens
temp_df.drop(columns = 'tax_liens', inplace=True)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(temp_df.corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
len(temp_df.columns)
# Out:
# 22

# %%
# create buckets of features for deeper EDA

delinq_features = ['delinq_2y', 'months_since_last_delinq', 'num_historical_failed_to_pay', 'months_since_90d_late', 'num_accounts_120d_past_due', 'num_accounts_30d_past_due', 'account_never_delinq_percent', 'interest_rate']

credit_activity = ['years_since_first_credit', 'inquiries_last_12m', 'open_credit_lines', 'total_credit_utilized', 'months_since_last_credit_inquiry', 'interest_rate']

limit_utilisation = ['total_debit_limit', 'total_credit_limit', 'interest_rate']

account_composition = ['current_installment_accounts', 'accounts_opened_24m', 'num_active_debit_accounts', 'num_mort_accounts', 'interest_rate']

public_records = ['num_collections_last_12m', 'total_collection_amount_ever', 'public_record_bankrupt', 'interest_rate']

# %% [markdown]
# Analysing Delinq features

# %%
temp_df
# Out:
#       delinq_2y  months_since_last_delinq  years_since_first_credit  \
# 0             0                      38.0                        24
# 1             0                     119.0                        29
# 2             0                      28.0                        19
# 3             0                     119.0                        18
# 4             0                     119.0                        17
# ...         ...                       ...                       ...
# 9995          0                     119.0                        17
# 9996          4                       9.0                        31
# 9997          2                       6.0                        21
# 9998          0                     119.0                        26
# 9999          0                     119.0                        20
#
#       inquiries_last_12m  open_credit_lines  total_credit_limit  \
# 0                      6                 10               70795
# 1                      1                 14               28800
# 2                      4                 10               24193
# 3                      0                  4               25400
# 4                      7                 16               69839
# ...                  ...                ...                 ...
# 9995                   5                 13              199195
# 9996                   1                 15              382061
# 9997                   0                 11              346402
# 9998                   1                 15              294475
# 9999                   0                 11               91887
#
#       total_credit_utilized  num_collections_last_12m  \
# 0                     38767                         0
# 1                      4321                         0
# 2                     16000                         0
# 3                      4997                         0
# 4                     52722                         0
# ...                     ...                       ...
# 9995                  77963                         0
# 9996                 101571                         0
# 9997                  95421                         0
# 9998                  27641                         0
# 9999                  53413                         0
#
#       num_historical_failed_to_pay  months_since_90d_late  \
# 0                                0                   38.0
# 1                                1                  129.0
# 2                                0                   28.0
# 3                                1                  129.0
# 4                                0                  129.0
# ...                            ...                    ...
# 9995                             1                  129.0
# 9996                             0                    9.0
# 9997                             0                  129.0
# 9998                             0                  129.0
# 9999                             0                  129.0
#
#       total_collection_amount_ever  current_installment_accounts  \
# 0                             1250                             2
# 1                                0                             0
# 2                              432                             1
# 3                                0                             1
# 4                                0                             1
# ...                            ...                           ...
# 9995                             0                             3
# 9996                             0                             3
# 9997                             0                             3
# 9998                             0                             2
# 9999                             0                             5
#
#       accounts_opened_24m  months_since_last_credit_inquiry  \
# 0                       5                               5.0
# 1                      11                               8.0
# 2                      13                               7.0
# 3                       1                              15.0
# 4                       6                               4.0
# ...                   ...                               ...
# 9995                    8                               6.0
# 9996                    0                               1.0
# 9997                    4                              16.0
# 9998                    2                               5.0
# 9999                    4                              18.0
#
#       num_accounts_120d_past_due  num_accounts_30d_past_due  \
# 0                            0.0                          0
# 1                            0.0                          0
# 2                            0.0                          0
# 3                            0.0                          0
# 4                            0.0                          0
# ...                          ...                        ...
# 9995                         0.0                          0
# 9996                         0.0                          0
# 9997                         0.0                          0
# 9998                         0.0                          0
# 9999                         0.0                          0
#
#       num_active_debit_accounts  total_debit_limit  num_mort_accounts  \
# 0                             2              11100                  1
# 1                             3              16500                  0
# 2                             3               4300                  0
# 3                             2              19400                  0
# 4                            10              32700                  0
# ...                         ...                ...                ...
# 9995                          4              44600                  1
# 9996                          5              28200                  2
# 9997                          5              14900                  2
# 9998                          1              46000                  6
# 9999                          5              36800                  0
#
#       account_never_delinq_percent  public_record_bankrupt  interest_rate
# 0                             92.9                       0          14.07
# 1                            100.0                       1          12.61
# 2                             93.5                       0          17.09
# 3                            100.0                       0           6.72
# 4                            100.0                       0          14.07
# ...                            ...                     ...            ...
# 9995                         100.0                       1           7.35
# 9996                          82.1                       0          19.03
# 9997                          72.2                       0          23.88
# 9998                         100.0                       0           5.32
# 9999                         100.0                       0          10.91
#
# [10000 rows x 22 columns]

# %%
sns.heatmap(temp_df[delinq_features].corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
# only keep the features with corr of higher than 1 with interest rate in delinq_features
temp_df.drop(columns = ['delinq_2y', 'num_historical_failed_to_pay', 'num_accounts_120d_past_due', 'num_accounts_30d_past_due'], inplace = True)

# %%
sns.histplot(temp_df['months_since_last_delinq']**2, kde=True)
# Out:
# <Axes: xlabel='months_since_last_delinq', ylabel='Count'>

# %%
temp_df['square_months_since_last_delinq'] = temp_df['months_since_last_delinq']**2

# %%
sns.histplot(temp_df['months_since_90d_late']**3, kde=True)
# Out:
# <Axes: xlabel='months_since_90d_late', ylabel='Count'>

# %%
temp_df['months_since_90d_late'].describe()
# Out:
# count    10000.000000
# mean       110.060200
# std         36.322402
# min          2.000000
# 25%        129.000000
# 50%        129.000000
# 75%        129.000000
# max        129.000000
# Name: months_since_90d_late, dtype: float64

# %%
# month_since_90d_late == 129 (max), create a new column 'never_late'
temp_df['never_late_payment'] = (temp_df['months_since_90d_late'] == 129).astype(int)

# %%
# temp_df.loc[temp_df['never_late_payment'] == 1, 'months_since_90d_late'] = np.nan

# %%
sns.histplot(temp_df['months_since_90d_late'], kde=True)
# Out:
# <Axes: xlabel='months_since_90d_late', ylabel='Count'>

# %%
temp_df['never_late_payment'].value_counts()
# Out:
# never_late_payment
# 1    7715
# 0    2285
# Name: count, dtype: int64

# %%
sns.boxplot(x= temp_df['never_late_payment'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='never_late_payment', ylabel='interest_rate'>

# %%
np.max(temp_df['months_since_90d_late'])
# Out:
# np.float64(129.0)

# %%
sns.histplot(temp_df['account_never_delinq_percent'])
# Out:
# <Axes: xlabel='account_never_delinq_percent', ylabel='Count'>

# %%
# temp_df['delinq_risk_category']
temp_df['delinq_risk_category'] = pd.cut(temp_df['account_never_delinq_percent'], bins = [-1, 80, 95, 99, 100], labels= ['High Risk', 'Moderate Risk', 'Low Risk', 'Perfect'])

# %%
sns.boxplot(x = temp_df['delinq_risk_category'], y= temp_df['interest_rate'])
# Out:
# <Axes: xlabel='delinq_risk_category', ylabel='interest_rate'>

# %% [markdown]
# Analysing Credit activity features

# %%
credit_activity = ['years_since_first_credit', 'inquiries_last_12m', 'open_credit_lines', 'total_credit_utilized', 'months_since_last_credit_inquiry', 'interest_rate']

# %%
temp_df[credit_activity].corr()
# Out:
#                                   years_since_first_credit  \
# years_since_first_credit                          1.000000
# inquiries_last_12m                               -0.042745
# open_credit_lines                                 0.174322
# total_credit_utilized                             0.140936
# months_since_last_credit_inquiry                  0.020712
# interest_rate                                    -0.103635
#
#                                   inquiries_last_12m  open_credit_lines  \
# years_since_first_credit                   -0.042745           0.174322
# inquiries_last_12m                          1.000000           0.186462
# open_credit_lines                           0.186462           1.000000
# total_credit_utilized                       0.120593           0.406047
# months_since_last_credit_inquiry           -0.578027          -0.192809
# interest_rate                               0.131193          -0.012773
#
#                                   total_credit_utilized  \
# years_since_first_credit                       0.140936
# inquiries_last_12m                             0.120593
# open_credit_lines                              0.406047
# total_credit_utilized                          1.000000
# months_since_last_credit_inquiry              -0.100377
# interest_rate                                  0.031527
#
#                                   months_since_last_credit_inquiry  \
# years_since_first_credit                                  0.020712
# inquiries_last_12m                                       -0.578027
# open_credit_lines                                        -0.192809
# total_credit_utilized                                    -0.100377
# months_since_last_credit_inquiry                          1.000000
# interest_rate                                            -0.133645
#
#                                   interest_rate
# years_since_first_credit              -0.103635
# inquiries_last_12m                     0.131193
# open_credit_lines                     -0.012773
# total_credit_utilized                  0.031527
# months_since_last_credit_inquiry      -0.133645
# interest_rate                          1.000000

# %%
sns.heatmap(temp_df[credit_activity].corr(), cmap= 'coolwarm', annot=True)
# Out:
# <Axes: >

# %%
temp_df.drop(columns = ['years_since_first_credit', 'open_credit_lines', 'total_credit_utilized', 'months_since_last_credit_inquiry'], inplace = True)

# %%
sns.scatterplot(x = (temp_df['inquiries_last_12m']), y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='inquiries_last_12m', ylabel='interest_rate'>

# %% [markdown]
# Limit_utilisation feature analysis

# %%
limit_utilisation = ['total_debit_limit', 'total_credit_limit', 'interest_rate']

# %%
sns.heatmap(temp_df[limit_utilisation].corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
# drop total_credit_limit
temp_df.drop(columns = 'total_credit_limit', inplace=True)

# %%
sns.histplot(temp_df['total_debit_limit'])
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='Count'>

# %%
sns.histplot(np.log1p(temp_df['total_debit_limit']), kde = True)
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='Count'>

# %%
# temp_index = temp_df[temp_df['total_debit_limit'] > temp_df['total_debit_limit'].quantile(0.99)]

# %%
# temp_df.drop(index = temp_index.index, inplace =True)

# %%
sns.histplot(temp_df['total_debit_limit'])
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='Count'>

# %%
sns.histplot(np.log1p(temp_df['total_debit_limit']))
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='Count'>

# %%
sns.scatterplot(x = np.log1p(temp_df['total_debit_limit']), y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='interest_rate'>

# %%
sns.scatterplot(x = temp_df['total_debit_limit'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='interest_rate'>

# %%
sns.regplot(x=np.log1p(temp_df['total_debit_limit']), y=temp_df["interest_rate"])
# Out:
# <Axes: xlabel='total_debit_limit', ylabel='interest_rate'>

# %%
temp_df['log_total_debit_limit'] = np.log1p(temp_df['total_debit_limit'])

# %% [markdown]
# Account composition feature analysis

# %%
account_composition = ['current_installment_accounts', 'accounts_opened_24m', 'num_active_debit_accounts', 'num_mort_accounts', 'interest_rate']

# %%
temp_df[account_composition]
# Out:
#       current_installment_accounts  accounts_opened_24m  \
# 0                                2                    5
# 1                                0                   11
# 2                                1                   13
# 3                                1                    1
# 4                                1                    6
# ...                            ...                  ...
# 9995                             3                    8
# 9996                             3                    0
# 9997                             3                    4
# 9998                             2                    2
# 9999                             5                    4
#
#       num_active_debit_accounts  num_mort_accounts  interest_rate
# 0                             2                  1          14.07
# 1                             3                  0          12.61
# 2                             3                  0          17.09
# 3                             2                  0           6.72
# 4                            10                  0          14.07
# ...                         ...                ...            ...
# 9995                          4                  1           7.35
# 9996                          5                  2          19.03
# 9997                          5                  2          23.88
# 9998                          1                  6           5.32
# 9999                          5                  0          10.91
#
# [10000 rows x 5 columns]

# %%
temp_df[account_composition].corr()
# Out:
#                               current_installment_accounts  \
# current_installment_accounts                      1.000000
# accounts_opened_24m                               0.157638
# num_active_debit_accounts                         0.026708
# num_mort_accounts                                 0.004717
# interest_rate                                     0.047131
#
#                               accounts_opened_24m  num_active_debit_accounts  \
# current_installment_accounts             0.157638                   0.026708
# accounts_opened_24m                      1.000000                   0.272818
# num_active_debit_accounts                0.272818                   1.000000
# num_mort_accounts                        0.106556                   0.040865
# interest_rate                            0.120657                   0.026800
#
#                               num_mort_accounts  interest_rate
# current_installment_accounts           0.004717       0.047131
# accounts_opened_24m                    0.106556       0.120657
# num_active_debit_accounts              0.040865       0.026800
# num_mort_accounts                      1.000000      -0.138351
# interest_rate                         -0.138351       1.000000

# %%
sns.heatmap(temp_df[account_composition].corr(), cmap='coolwarm', annot= True)
# Out:
# <Axes: >

# %%
# drop current_install_ment_accounts
temp_df.drop(columns = 'current_installment_accounts', inplace = True)

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x = temp_df['accounts_opened_24m'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='accounts_opened_24m', ylabel='interest_rate'>

# %%
sns.boxplot(x = temp_df['num_active_debit_accounts'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='num_active_debit_accounts', ylabel='interest_rate'>

# %%
sns.histplot(np.log1p(temp_df['num_active_debit_accounts']))
# Out:
# <Axes: xlabel='num_active_debit_accounts', ylabel='Count'>

# %%
temp_df['log_num_active_debit_accounts'] = np.log1p(temp_df['num_active_debit_accounts'])

# %%
sns.scatterplot(x = temp_df['log_num_active_debit_accounts'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='log_num_active_debit_accounts', ylabel='interest_rate'>

# %%
sns.boxplot(x = temp_df['num_mort_accounts'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='num_mort_accounts', ylabel='interest_rate'>

# %% [markdown]
# Public record features analysis

# %%
public_records = ['num_collections_last_12m', 'total_collection_amount_ever', 'public_record_bankrupt', 'interest_rate']

# %%
temp_df[public_records].corr()
# Out:
#                               num_collections_last_12m  \
# num_collections_last_12m                      1.000000
# total_collection_amount_ever                  0.027804
# public_record_bankrupt                       -0.011918
# interest_rate                                 0.029901
#
#                               total_collection_amount_ever  \
# num_collections_last_12m                          0.027804
# total_collection_amount_ever                      1.000000
# public_record_bankrupt                           -0.009645
# interest_rate                                     0.013532
#
#                               public_record_bankrupt  interest_rate
# num_collections_last_12m                   -0.011918       0.029901
# total_collection_amount_ever               -0.009645       0.013532
# public_record_bankrupt                      1.000000       0.047477
# interest_rate                               0.047477       1.000000

# %%
sns.heatmap(temp_df[public_records].corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
temp_df['num_collections_last_12m'].value_counts()
# Out:
# num_collections_last_12m
# 0    9873
# 1     117
# 2       9
# 3       1
# Name: count, dtype: int64

# %%
sns.boxplot(x = temp_df['num_collections_last_12m'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='num_collections_last_12m', ylabel='interest_rate'>

# %%
temp_df.drop(columns = 'num_collections_last_12m', inplace = True)

# %%
temp_df['total_collection_amount_ever'].value_counts()
# Out:
# total_collection_amount_ever
# 0       8635
# 100       12
# 50        10
# 150        9
# 96         9
#         ...
# 4562       1
# 3191       1
# 968        1
# 144        1
# 1323       1
# Name: count, Length: 896, dtype: int64

# %%
temp_df.drop(columns = 'total_collection_amount_ever', inplace = True)

# %%
sns.boxplot(x = temp_df['public_record_bankrupt'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='public_record_bankrupt', ylabel='interest_rate'>

# %%
temp_df['public_record_bankrupt'].value_counts()
# Out:
# public_record_bankrupt
# 0    8785
# 1    1195
# 2      17
# 3       3
# Name: count, dtype: int64

# %%
temp_df['has_bankruptcy'] = (temp_df['public_record_bankrupt'] > 0).astype(int)

# %%
sns.boxplot(x = temp_df['has_bankruptcy'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='has_bankruptcy', ylabel='interest_rate'>

# %%
temp_df.to_csv('C:/Users/apaks/Desktop/Data Science/Python/Python Playground/Projects/Machine Learning Projects/Loan Data from Lending Club/data/preprocessing_stage_2.csv')

# %%
credit_history_df = temp_df

# %% [markdown]
# ## EDA - loan_details

# %%
loan_details_df = df[['loan_purpose', 'application_type', 'loan_amount', 'term', 'installment', 'grade', 'sub_grade', 'issue_month', 'initial_listing_status', 'disbursement_method','interest_rate']]

# %%
temp_df = loan_details_df.copy()

# %%
temp_df.head()
# Out:
#          loan_purpose application_type  loan_amount  term  installment grade  \
# 0              moving       individual        28000    60       652.53     C
# 1  debt_consolidation       individual         5000    36       167.54     C
# 2               other       individual         2000    36        71.40     D
# 3  debt_consolidation       individual        21600    36       664.19     A
# 4         credit_card            joint        23000    36       786.87     C
#
#   sub_grade issue_month initial_listing_status disbursement_method  \
# 0        C3    Mar-2018                  whole                Cash
# 1        C1    Feb-2018                  whole                Cash
# 2        D1    Feb-2018             fractional                Cash
# 3        A3    Jan-2018                  whole                Cash
# 4        C3    Mar-2018                  whole                Cash
#
#    interest_rate
# 0          14.07
# 1          12.61
# 2          17.09
# 3           6.72
# 4          14.07

# %% [markdown]
# Categorical columns

# %%
temp_df['loan_purpose'].value_counts()
# Out:
# loan_purpose
# debt_consolidation    5144
# credit_card           2249
# other                  914
# home_improvement       680
# major_purchase         303
# medical                162
# house                  151
# car                    131
# small_business         125
# moving                  69
# vacation                62
# renewable_energy        10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(x = temp_df['loan_purpose'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='loan_purpose', ylabel='interest_rate'>

# %%
rare_purpose = ['medical', 'house', 'car', 'small_business', 'moving', 'vacation', 'renewable_energy']
temp_df['loan_purpose'] = temp_df['loan_purpose'].apply(lambda x: x if x not in rare_purpose else 'other')

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(x = temp_df['loan_purpose'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='loan_purpose', ylabel='interest_rate'>

# %%
sns.boxplot(x = temp_df['application_type'], y = temp_df['interest_rate'])
# Out:
# <Axes: xlabel='application_type', ylabel='interest_rate'>

# %% [markdown]
# numeric columns

# %%
temp_df1 = temp_df[['loan_amount', 'term', 'installment', 'interest_rate']]

# %%
sns.heatmap(temp_df1.corr(), cmap = 'coolwarm', annot= True)
# Out:
# <Axes: >

# %%
temp_df.drop(columns = 'term', inplace= True)

# %%
temp_df
# Out:
#             loan_purpose application_type  loan_amount  installment grade  \
# 0                  other       individual        28000       652.53     C
# 1     debt_consolidation       individual         5000       167.54     C
# 2                  other       individual         2000        71.40     D
# 3     debt_consolidation       individual        21600       664.19     A
# 4            credit_card            joint        23000       786.87     C
# ...                  ...              ...          ...          ...   ...
# 9995               other       individual        24000       744.90     A
# 9996  debt_consolidation       individual        10000       366.72     D
# 9997  debt_consolidation            joint        30000      1175.10     E
# 9998               other       individual        24000       722.76     A
# 9999         credit_card       individual        12800       418.52     B
#
#      sub_grade issue_month initial_listing_status disbursement_method  \
# 0           C3    Mar-2018                  whole                Cash
# 1           C1    Feb-2018                  whole                Cash
# 2           D1    Feb-2018             fractional                Cash
# 3           A3    Jan-2018                  whole                Cash
# 4           C3    Mar-2018                  whole                Cash
# ...        ...         ...                    ...                 ...
# 9995        A4    Jan-2018                  whole                Cash
# 9996        D3    Feb-2018                  whole                Cash
# 9997        E2    Feb-2018             fractional                Cash
# 9998        A1    Feb-2018                  whole                Cash
# 9999        B4    Feb-2018                  whole                Cash
#
#       interest_rate
# 0             14.07
# 1             12.61
# 2             17.09
# 3              6.72
# 4             14.07
# ...             ...
# 9995           7.35
# 9996          19.03
# 9997          23.88
# 9998           5.32
# 9999          10.91
#
# [10000 rows x 10 columns]

# %%
temp_df.drop(columns = ['grade', 'sub_grade', 'issue_month', 'initial_listing_status', 'disbursement_method'], inplace = True)

# %%
# ['total_debit_limit'] > quantile(0.99) to be removed in the end

# %%
loan_details_df = temp_df

# %% [markdown]
# ## Merging all the 3 datasets

# %%
df_final = pd.concat(
    [borrower_profile_df, credit_history_df, loan_details_df],
    axis=1
)

# %%
# droping rows where total_debit_limit is higher than 99th percentile of that column 
tem_df = df_final[df_final['total_debit_limit'] > df_final['total_debit_limit'].quantile(0.99)]

# %%
df_final.drop(index = tem_df.index, inplace = True)

# %%
df_final.to_csv('C:/Users/apaks/Desktop/Data Science/Python/Python Playground/Projects/Machine Learning Projects/Loan Data from Lending Club/data/preprocessing_stage_3.csv')
